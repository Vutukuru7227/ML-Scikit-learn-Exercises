# %%
import sklearn
import numpy as np
from sklearn.neural_network import MLPClassifier as MLPC

# %%
X = np.array([[0,0],
             [0,1],
             [1,0],
             [1,1]])
Y = np.array([0,1,1,0])

print(X)
print(Y)
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]]
# [0 1 1 0]

# %%
clf = MLPC(activation="tanh", max_iter = 10000, hidden_layer_sizes=(5), verbose=True)
clf.fit(X,Y);

print("Score " + str(model.score(X,Y)))
print("Expected " + str(Y))
print("Predicted " + str(model.predict(X)))
# Out:
# Iteration 1, loss = 0.70957688
# Iteration 2, loss = 0.70895719
# Iteration 3, loss = 0.70834633
# Iteration 4, loss = 0.70774444
# Iteration 5, loss = 0.70715163
# Iteration 6, loss = 0.70656802
# Iteration 7, loss = 0.70599370
# Iteration 8, loss = 0.70542876
# Iteration 9, loss = 0.70487328
# Iteration 10, loss = 0.70432731
# Iteration 11, loss = 0.70379091
# Iteration 12, loss = 0.70326411
# Iteration 13, loss = 0.70274692
# Iteration 14, loss = 0.70223935
# Iteration 15, loss = 0.70174139
# Iteration 16, loss = 0.70125301
# Iteration 17, loss = 0.70077417
# Iteration 18, loss = 0.70030482
# Iteration 19, loss = 0.69984487
# Iteration 20, loss = 0.69939424
# Iteration 21, loss = 0.69895283
# Iteration 22, loss = 0.69852051
# Iteration 23, loss = 0.69809715
# Iteration 24, loss = 0.69768260
# Iteration 25, loss = 0.69727669
# Iteration 26, loss = 0.69687924
# Iteration 27, loss = 0.69649007
# Iteration 28, loss = 0.69610897
# Iteration 29, loss = 0.69573571
# ...
